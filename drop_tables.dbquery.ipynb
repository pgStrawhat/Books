-- %%
--DROP TABLE workspace.default.bronze_test_table;
--DROP TABLE workspace.default.silver_test_table;

select * from workspace.default.bronze_test_table;
select * from workspace.default.silver_test_table;
